# %%
import pandas as pd
df = pd.read_csv('Bangla.csv')
df.head()
# Out:
#         Name             Start Datetime               End Datetime     Time  \
# 0  JO001KJDS  2021-06-08 10:04:01+06:00  2021-06-08 10:24:05+06:00  0:20:00
# 1  JO003KDJF  2021-06-08 10:00:31+06:00  2021-06-08 10:05:22+06:00  0:04:28
# 2  JO007KDJD  2021-06-08 10:00:36+06:00  2021-06-08 10:12:23+06:00  0:11:25
# 3  JO009HEGR  2021-06-08 10:00:39+06:00  2021-06-08 10:08:31+06:00  0:07:28
# 4  JO013JSHE  2021-06-08 10:01:12+06:00  2021-06-08 10:18:06+06:00  0:12:02
#
#    Percent  Points Earned  Points Possible  \
# 0       60           12.0             20.0
# 1       95           19.0             20.0
# 2       95           19.0             20.0
# 3       85           17.0             20.0
# 4       95           19.0             20.0
#
#    ‘লালসালু’ উপন্যাসে কোন সড়কের ওপর এক অপরিচিত লোক মোনাজাতের ভঙ্গিতে দাঁড়িয়ে আছে?  \
# 0                                                0.0
# 1                                                1.0
# ...

# %%
df = df.drop([7:25], axis ='columns')
df.head()
# Out:
#   File "<ipython-input-11-857fca160c5f>", line 1
#     df = df.drop([7:25], axis ='columns')
#                    ^
# SyntaxError: invalid syntax

# %%
df.shape
# Out:
# (368, 26)

# %%
df.head()
# Out:
#         Name             Start Datetime               End Datetime     Time  \
# 0  JO001KJDS  2021-06-08 10:04:01+06:00  2021-06-08 10:24:05+06:00  0:20:00
# 1  JO003KDJF  2021-06-08 10:00:31+06:00  2021-06-08 10:05:22+06:00  0:04:28
# 2  JO007KDJD  2021-06-08 10:00:36+06:00  2021-06-08 10:12:23+06:00  0:11:25
# 3  JO009HEGR  2021-06-08 10:00:39+06:00  2021-06-08 10:08:31+06:00  0:07:28
# 4  JO013JSHE  2021-06-08 10:01:12+06:00  2021-06-08 10:18:06+06:00  0:12:02
#
#    Percent  Points Earned  \
# 0       60           12.0
# 1       95           19.0
# 2       95           19.0
# 3       85           17.0
# 4       95           19.0
#
#    ‘লালসালু’ উপন্যাসে কোন সড়কের ওপর এক অপরিচিত লোক মোনাজাতের ভঙ্গিতে দাঁড়িয়ে আছে?  \
# 0                                                0.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# ...

# %%
df = df.drop([['Start Datetime', 'End DateTime', 'Time']], axis ='columns')
df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-a1591f97e51f> in <module>
# ----> 1 df = df.drop([['Start Datetime', 'End DateTime', 'Time']], axis ='columns')
#       2 df.head()
#
# ~\anaconda33\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda33\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# -> 4153                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4154
#    4155         if inplace:
#
# ...

# %%
df = df.drop(['হাসুনির মায়ের প্রতি মজিদের কোন দৃষ্টিভঙ্গির প্রকাশ ঘটেছে?'], axis ='columns')
df.head()
# Out:
#         Name  Percent  Points Earned  \
# 0  JO001KJDS       60           12.0
# 1  JO003KDJF       95           19.0
# 2  JO007KDJD       95           19.0
# 3  JO009HEGR       85           17.0
# 4  JO013JSHE       95           19.0
#
#    ‘লালসালু’ উপন্যাসে মজিদের সাম্রাজ্য পতনে নিচের কোন বিষয়টি গ্রহণযোগ্য?  \
# 0                                               -3.0
# 1                                                1.0
# 2                                                1.0
# 3                                                0.0
# 4                                                1.0
#
#    ‘লালসালু’ উপন্যাসে রহিমা চরিত্রে কোন বিষয়টি প্রকাশ পেয়েছে?  \
# 0                                                0.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
#    ‘লালসালু’ উপন্যাসের নায়িকা চরিত্র কোনটি?  \
# ...

# %%
df.to_csv("BanglaFinal.csv", index = False)

# %%
BanglaFinal.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-5b6ea988ffe2> in <module>
# ----> 1 BanglaFinal.head()
#
# NameError: name 'BanglaFinal' is not defined
