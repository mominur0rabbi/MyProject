# %%
import pandas as pd
import os

# %%
files =[file for file in os.listdir('.\SecondTermXI')]
for file in files:
    print(file)
# Out:
# Eng (1).csv
# Eng (2).csv
# Eng (3).csv
# Eng (4).csv
# Eng (5).csv

# %%
files =[file for file in os.listdir("./SecondTermXI")]
All_Eng = pd.DataFrame()
for file in files:
    df = pd.read_csv("./SecondTermXI/" + file)
    All_Eng = pd.concat([All_Eng, df])
All_Eng.head()
# Out:
#         Name             Start Datetime               End Datetime     Time  \
# 0  JO001KJDS  2021-06-12 10:04:40+06:00  2021-06-12 10:23:47+06:00  0:17:00
# 1  JO003KDJF  2021-06-12 10:00:27+06:00  2021-06-12 10:17:47+06:00  0:16:13
# 2  JO004MFNG  2021-06-12 10:00:55+06:00  2021-06-12 10:25:47+06:00  0:24:31
# 3  JO007KDJD  2021-06-12 10:00:21+06:00  2021-06-12 10:15:01+06:00  0:14:16
# 4  JO009HEGR  2021-06-12 10:00:36+06:00  2021-06-12 10:23:14+06:00  0:22:13
#
#    Percent  Points Earned  Points Possible  রেওয়ামিল তৈরির মূল উদ্দেশ্য কী?  \
# 0       45            9.0             20.0                               1.0
# 1       75           15.0             20.0                               1.0
# 2       60           12.0             20.0                               0.0
# 3       80           16.0             20.0                               1.0
# 4       80           16.0             20.0                               1.0
#
#    কোনটি রেওয়ামিলের ক্রেডিট দিকে বসে?  \
# ...

# %%
All_Eng.to_csv("All_Bstudies.csv", index = False)

# %%
Biology.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-186c34a5a908> in <module>
# ----> 1 Biology.head()
#
# NameError: name 'Biology' is not defined

# %%
bio =pd.read_csv("Biolo.csv")
che =pd.read_csv("Chem.csv")
joinBio_Che = pd.merge(bio, che)
joinBio_Che
# Out:
#            Name  Biol  Che
# 0     NE232SMDK    14   12
# 1     NE235KRJF    15    6
# 2     NE236MSKE    12   11
# 3     NE237MSHS    17   16
# 4    NE239KMDJF    16    8
# ..          ...   ...  ...
# 279   NU086RTER    10   15
# 280   NU087HFDS    11    8
# 281   NU089GRET    17   11
# 282   NU090NFTH    17   14
# 283   NU091BFDS     9   12
#
# [284 rows x 3 columns]

# %%
joinBio_Che.to_csv("JoinC_B.csv")

# %%
bio
# Out:
#            Name  Biol
# 0     NE232SMDK    14
# 1     NE235KRJF    15
# 2     NE236MSKE    12
# 3     NE237MSHS    17
# 4    NE239KMDJF    16
# ..          ...   ...
# 308   NU086RTER    10
# 309   NU087HFDS    11
# 310   NU089GRET    17
# 311   NU090NFTH    17
# 312   NU091BFDS     9
#
# [313 rows x 2 columns]

# %%
All_Data =pd.read_csv("MainData.csv")

# %%
All_Data
# Out:
#             ID  Roll
# 0    LU001URTY     1
# 1    LU002FJHJ     2
# 2    LU003NCBJ     3
# 3    NU004DHJS     4
# 4    LU005DJKH     5
# ..         ...   ...
# 386  PL403KJSD   403
# 387  UR404JKDE   404
# 388  UR405HGTU   405
# 389  PL406KORI   406
# 390  PA407LABS   407
#
# [391 rows x 2 columns]

# %%
bio =pd.read_csv("Biolo.csv")

# %%
joinBio_Main = pd.merge(All_Data, bio)
joinBio_Main
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-39-c0489cd61d79> in <module>
# ----> 1 joinBio_Main = pd.merge(All_Data, bio)
#       2 joinBio_Main
#
# ~\anaconda33\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda33\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     648             warnings.warn(msg, UserWarning)
#     649
# --> 650         self._validate_specification()
#     651
#     652         cross_col = None
#
# ...
