# %%
import pandas as pd

# %%
df = pd.read_csv('50contacts.csv')
df
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 9        Kris    Marrier        King, Christopher A Esq
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# ...

# %%
df.columns
# Out:
# Index(['first_name', 'last_name', 'company_name', 'address', 'city', 'county',
#        'state', 'zip', 'phone1', 'phone', 'email'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['first_name',
#  'last_name',
#  'company_name',
#  'address',
#  'city',
#  'county',
#  'state',
#  'zip',
#  'phone1',
#  'phone',
#  'email']

# %%
df[['first_name','city']]
# Out:
#    first_name             city
# 0       James      New Orleans
# 1   Josephine         Brighton
# 2         Art       Bridgeport
# 3       Lenna        Anchorage
# 4     Donette         Hamilton
# 5      Simona          Ashland
# 6      Mitsue          Chicago
# 7       Leota         San Jose
# 8        Sage      Sioux Falls
# 9        Kris        Baltimore
# 10      Minna       Kulpsville
# 11       Abel    Middle Island
# 12      Kiley      Los Angeles
# 13   Graciela    Chagrin Falls
# 14      Cammy           Laredo
# 15     Mattie          Phoenix
# 16    Meaghan     Mc Minnville
# 17     Gladys        Milwaukee
# 18       Yuki           Taylor
# 19   Fletcher         Rockford
# 20      Bette            Aston
# 21   Veronika         San Jose
# 22    Willard           Irving
# 23    Maryann           Albany
# 24     Alisha        Middlesex
# 25     Allene    Stevens Point
# 26     Chanel          Shawnee
# 27    Ezekiel           Easton
# 28     Willow         New York
# ...

# %%
dfNewYouk = df[df['city']=='New York']

# %%
dfNewYouk
# Out:
#    first_name last_name             company_name                address  \
# 28     Willow     Kusko                U Pull It     90991 Thorburn Ave
# 34    Alishia     Sergi  Milford Enterprises Inc  2742 Distribution Way
# 36       Jose  Stockham    Tri State Refueler Co        128 Bransten Rd
#
#         city    county state    zip        phone1         phone  \
# 28  New York  New York    NY  10011  212-582-4976  212-934-5167
# 34  New York  New York    NY  10025  212-860-1579  212-753-2740
# 36  New York  New York    NY  10011  212-675-8570  212-569-4233
#
#                email
# 28  wkusko@yahoo.com
# 34  asergi@gmail.com
# 36    jose@yahoo.com

# %%
dfNewYouk['zip'].sum()
# Out:
# 30047

# %%
df[(df['city']=='New York') & (df['zip']==10011) ]
# Out:
#    first_name last_name           company_name             address      city  \
# 28     Willow     Kusko              U Pull It  90991 Thorburn Ave  New York
# 36       Jose  Stockham  Tri State Refueler Co     128 Bransten Rd  New York
#
#       county state    zip        phone1         phone             email
# 28  New York    NY  10011  212-582-4976  212-934-5167  wkusko@yahoo.com
# 36  New York    NY  10011  212-675-8570  212-569-4233    jose@yahoo.com

# %%
df[(df['city']=='Miami') ]
# Out:
#    first_name last_name         company_name      address   city      county  \
# 43     Lavera     Perin  Abc Enterprises Inc  678 3rd Ave  Miami  Miami-Dade
#
#    state    zip        phone1         phone             email
# 43    FL  33196  305-606-7291  305-995-2078  lperin@perin.org

# %%
df[df['zip']>55343]
# Out:
#    first_name  last_name                   company_name              address  \
# 0       James       Butt              Benton, John B Jr   6649 N Blue Gum St
# 3       Lenna   Paprocki         Feltz Printing Service          639 Main St
# 6      Mitsue    Tollner             Morlong Associates            7 Eads St
# 7       Leota   Dilliard               Commercial Press     7 W Jackson Blvd
# 8        Sage     Wieser      Truhlar And Truhlar Attys     5 Boston Ave #88
# 12      Kiley  Caldarera                    Feiner Bros     25 E 75th St #69
# 14      Cammy    Albares         Rousseaux, Michael Esq     56 E Morehead St
# 15     Mattie   Poquette         Century Communications  73 State Road 434 E
# 19   Fletcher      Flosi         Post Box Services Plus  394 Manchester Blvd
# 21   Veronika     Inouye                C 4 Network Inc      6 Greenleaf Ave
# 22    Willard    Kolmetz          Ingalls, Donald R Esq     618 W Yakima Ave
# ...

# %%
df.groupby(['city'])['zip'].count()
# Out:
# city
# Abilene            1
# Albany             1
# Anchorage          1
# Ashland            1
# Aston              1
# Baltimore          1
# Boston             1
# Bridgeport         1
# Brighton           1
# Camarillo          1
# Chagrin Falls      1
# Chicago            1
# Columbus           1
# Conroe             1
# Dunellen           1
# Easton             1
# Fairbanks          2
# Hamilton           1
# Hopkins            1
# Irving             1
# Kulpsville         1
# Laredo             1
# Las Cruces         1
# Los Angeles        2
# Madison            1
# Mc Minnville       1
# Metairie           1
# Miami              1
# Middle Island      1
# Middlesex          1
# Milwaukee          1
# New Orleans        1
# New York           3
# Overland Park      1
# Philadelphia       1
# Phoenix            1
# Prineville         1
# Ridgefield Park    1
# Rockford           1
# San Antonio        1
# San Jose           2
# Shawnee            1
# Sioux Falls        1
# ...

# %%
pd.read_csv('http://blockchainainyc.com/wp-content/uploads/2018/06/avgsal-2.csv')
# Out:
#   City  Avg Salary
# 0    M       15000
# 1    B       17000
# 2    Q       10000

# %%
pd.melt(df,['city'])
# Out:
#              city    variable                       value
# 0     New Orleans  first_name                       James
# 1        Brighton  first_name                   Josephine
# 2      Bridgeport  first_name                         Art
# 3       Anchorage  first_name                       Lenna
# 4        Hamilton  first_name                     Donette
# ..            ...         ...                         ...
# 495       Hopkins       email        fsaylors@saylors.org
# 496        Boston       email  jina_briddick@briddick.com
# 497   Los Angeles       email   kanisha_waycott@yahoo.com
# 498       Madison       email   emerson.bowley@bowley.org
# 499  Philadelphia       email            bmalet@yahoo.com
#
# [500 rows x 3 columns]

# %%
df = pd.DataFrame({'key': ['foo', 'bar', 'baz'],
                   'A': [1, 2, 3],
                   'B': [4, 5, 6],
                   'C': [7, 8, 9]})
df
# Out:
#    key  A  B  C
# 0  foo  1  4  7
# 1  bar  2  5  8
# 2  baz  3  6  9

# %%
melted = pd.melt(df, ['key'])
melted
# Out:
#    key variable  value
# 0  foo        A      1
# 1  bar        A      2
# 2  baz        A      3
# 3  foo        B      4
# 4  bar        B      5
# 5  baz        B      6
# 6  foo        C      7
# 7  bar        C      8
# 8  baz        C      9
