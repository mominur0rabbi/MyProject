# %%
# import pandaa and Numpy
import pandas as pd
import numpy as np

# %%
# Read csv files
df = pd.read_csv('X_Result.csv')

# %%
df.head()
# Out:
#     ID  BANCQ  BAN20  EngCQ  Eng20  GMathCQ  GMath20  BGSCQ  BGS20  ReliCQ  \
# 0  1.0   20.0    8.0   10.0   15.0     27.0      7.0   20.0   14.0    23.0
# 1  2.0   21.0   11.0   15.0   18.0     27.0      7.0   19.0   10.0    29.0
# 2  3.0   16.0    6.0    6.0    6.0      0.0      0.0   11.0    0.0    17.0
# 3  4.0   15.0    8.0   17.0   15.0     18.0      8.0   20.0   12.0    25.0
# 4  5.0   26.0   13.0   18.0   11.0     29.0      7.0   25.0   13.0    29.0
#
#    ...  ReliGL  GMathTTL  GMathGP  GMathGL  EngTTL  EngGP  EngGL  BANTTL  \
# 0  ...      A-      34.0      3.5       A-    25.0    3.0      B    28.0
# 1  ...      A+      34.0      3.5       A-    33.0    3.5     A-    32.0
# 2  ...       B       0.0      0.0        F    12.0    0.0      F    22.0
# 3  ...       A      26.0      3.0        B    32.0    3.5     A-    23.0
# 4  ...       A      36.0      4.0        A    29.0    3.0      B    39.0
#
#    BANGP  BANGL
# 0    3.0      B
# 1    3.5     A-
# 2    2.0      C
# ...

# %%
# Sum Two Column, Make Grade point and Later Grade on new Sum
df['CheTTL'] = df['CheCQ']+df['Che20']
df['CheGP'] =np.where(df['CheTTL']>39, 5, np.where(df['CheTTL']>34, 4,np.where(df['CheTTL']>29, 3.5,np.where(df['CheTTL']>24, 3, np.where(df['CheTTL']>19, 2,0)))))
df['CheGL'] =np.where(df['CheGP']==5, 'A+', np.where(df['CheGP']==4, 'A',np.where(df['CheGP']==3.5, 'A-',np.where(df['CheGP']==3, 'B', np.where(df['CheGP']==2, 'C','F')))))

# %%
df = df.round({'GPA': 2})
df.head()
# Out:
#    ID  BANCQ  BAN20  ENGCQ  ENG20  MathCQ  Math20  BGSCQ  BGS20  ReliCQ  ...  \
# 0   1     23     16     20     19      30      18     27     18      29  ...
# 1   2     22     12     18     10      30       6     27      8      29  ...
# 2   3      0      8      0      7       0      19      0     17       0  ...
# 3   4     23     17     21     17      28       9     14     12       0  ...
# 4   5     24     17     26     13      29      14     22     16      29  ...
#
#    CheGL  BioTTL  BioGP  BioGL  HMTTL  HMGP  HMGL  TTLMark  GPGPA   GPA
# 0     A+      44    5.0     A+     43   5.0    A+      383   42.0  4.67
# 1     A+      41    5.0     A+     15   0.0     F      316   33.5  3.72
# 2      F      16    0.0      F     11   0.0     F      119    0.0  0.00
# 3      A      21    2.0      C      5   0.0     F      220   22.0  2.44
# 4     A+      41    5.0     A+     44   5.0    A+      376   42.0  4.67
#
# [5 rows x 49 columns]

# %%
df.head()
# Out:
#    ID  BANCQ  BAN20  BanTTL  BanGP BanGL  ENGCQ  ENG20  EngTTL  EngGP  ...  \
# 0  43   24.0   16.0    40.0    5.0    A+   22.0   19.0    41.0    5.0  ...
# 1   7   25.0   13.0    38.0    4.0     A   25.0   15.0    40.0    5.0  ...
# 2  17   25.0   15.0    40.0    5.0    A+   17.0   12.0    29.0    3.0  ...
# 3   6   25.0   16.0    41.0    5.0    A+   20.0   15.0    35.0    4.0  ...
# 4   1   23.0   16.0    39.0    4.0     A   20.0   19.0    39.0    4.0  ...
#
#    HM20  HMTTL  HMGP  HMGL  TTLMark    Per  TTLGPA   GPA  LG  Position
# 0  19.0   43.0   5.0    A+    381.0  84.67    44.0  4.89   A         1
# 1  18.0   46.0   5.0    A+    386.0  85.78    43.0  4.78   A         2
# 2  15.0   43.0   5.0    A+    383.0  85.11    43.0  4.78   A         3
# 3  15.0   45.0   5.0    A+    382.0  84.89    43.0  4.78   A         4
# 4  15.0   43.0   5.0    A+    383.0  85.11    42.0  4.67   A         5
#
# [5 rows x 52 columns]

# %%
df.head()
# Out:
#     ID  BANCQ  BAN20  ENGCQ  ENG20  MathCQ  Math20  BGSCQ  BGS20  ReliCQ  ...  \
# 36  43     24     16     22     19      24      14     27     17      29  ...
# 6    7     25     13     25     15      30      17     26     10      29  ...
# 15  17     25     15     17     12      30      15     27     15      28  ...
# 5    6     25     16     20     15      30      17     24     15      29  ...
# 0    1     23     16     20     19      30      18     27     18      29  ...
#
#     CheGL  BioTTL  BioGP  BioGL  HMTTL  HMGP  HMGL  TTLMark  GPGPA   GPA
# 36     A+      43    5.0     A+     43   5.0    A+      381   44.0  4.89
# 6      A+      46    5.0     A+     46   5.0    A+      386   43.0  4.78
# 15     A+      46    5.0     A+     43   5.0    A+      383   43.0  4.78
# 5      A+      42    5.0     A+     45   5.0    A+      382   43.0  4.78
# 0      A+      44    5.0     A+     43   5.0    A+      383   42.0  4.67
#
# [5 rows x 49 columns]

# %%
cols = df.columns.tolist()
cols
# Out:
# ['ID',
#  'BANCQ',
#  'BAN20',
#  'EngCQ',
#  'Eng20',
#  'GMathCQ',
#  'GMath20',
#  'BGSCQ',
#  'BGS20',
#  'ReliCQ',
#  'Reli20',
#  'PhyCQ',
#  'Phy20',
#  'CheCQ',
#  'Che20',
#  'BioCQ',
#  'Bio20',
#  'ICT25',
#  'HMCQ',
#  'HM20',
#  'HMTTL',
#  'HMGP',
#  'HMGL',
#  'ICTGP',
#  'ICTGL',
#  'BioTTL',
#  'BioGP',
#  'BioGL',
#  'PhyTTL',
#  'PhyGP',
#  'PhyGL',
#  'BGSTTL',
#  'BGSGP',
#  'BGSGL',
#  'ReliTTL',
#  'ReliGP',
#  'ReliGL',
#  'GMathTTL',
#  'GMathGP',
#  'GMathGL',
#  'EngTTL',
#  'EngGP',
#  'EngGL',
#  'BANTTL',
#  'BANGP',
#  'BANGL',
#  'CheTTL',
#  'CheGP',
#  'CheGL']

# %%
#Grand Total of All Subject Total
df['TTLMark'] = df['BANTTL']+df['EngTTL']+df['GMathTTL']+df['BGSTTL']+df['ReliTTL']+df['PhyTTL']+df['CheTTL']+df['BioTTL']+df['ICT25']+df['HMTTL']

# %%
df['TTLGP'] = df['BANGP']+df['EngGP']+df['GMathGP']+df['BGSGP']+df['ReliGP']+df['PhyGP']+df['CheGP']+df['BioGP']+df['ICTGP']+df['HMGP']

# %%
df['AGP']=df['TTLGP']/10
df['LG'] =np.where(df['AGP']>=5, 'A+', np.where(df['AGP']>=4, 'A',np.where(df['AGP']>=3.5, 'A-',np.where(df['AGP']>=3, 'B', np.where(df['AGP']>=2, 'C','F')))))

# %%
df = df.sort_values(by=['TTLGP', 'TTLMark'], ascending=[False, False])

# %%
# Add Serial Number
df['Position'] = range(1, 1+len(df))

# %%
df
# Out:
#     ID  BANCQ  BAN20  ENGCQ  ENG20  MathCQ  Math20  BGSCQ  BGS20  ReliCQ  ...  \
# 36  43     24     16     22     19      24      14     27     17      29  ...
# 6    7     25     13     25     15      30      17     26     10      29  ...
# 15  17     25     15     17     12      30      15     27     15      28  ...
# 5    6     25     16     20     15      30      17     24     15      29  ...
# 0    1     23     16     20     19      30      18     27     18      29  ...
# 23  26     20     13     19     15      30      19     24     17      29  ...
# 4    5     24     17     26     13      29      14     22     16      29  ...
# 11  13     23     13     22     17      29      18     23     11      28  ...
# 10  12     25     11     27     14      30       9     27     11      29  ...
# 21  24     20     15     20     17      24      18     17     15      28  ...
# 12  14     24     14     18     13      30      10     25     15      26  ...
# ...

# %%
# Delete Column
del df['Per']

# %%
df.head()
# Out:
#    ID  BANCQ  BAN20  ENGCQ  ENG20  BGSCQ  BGS20  MathCQ  Math20  PhyCQ  ...  \
# 0   1   23.0   16.0   20.0   19.0   27.0   18.0    30.0    18.0   24.0  ...
# 1   2   22.0   12.0   18.0   10.0   27.0    8.0    30.0     6.0   27.0  ...
# 2   3    NaN    8.0    NaN    7.0    NaN   17.0     NaN    19.0    NaN  ...
# 3   4   23.0   17.0   21.0   17.0   14.0   12.0    28.0     9.0   16.0  ...
# 4   5   24.0   17.0   26.0   13.0   22.0   16.0    29.0    14.0   27.0  ...
#
#    CheTTL  CheGP  CheGL  MathTTL  MathGP  MathGL  TTLMark  TTLGPA       GPA  \
# 0    41.0    5.0     A+     48.0     5.0      A+    383.0    42.0  4.666667
# 1    43.0    5.0     A+     36.0     4.0       A      NaN    33.5  3.722222
# 2     NaN    0.0      F      NaN     0.0       F      NaN     0.0  0.000000
# 3    37.0    4.0      A     37.0     4.0       A      NaN    22.0  2.444444
# 4    47.0    5.0     A+     43.0     5.0      A+    376.0    42.0  4.666667
#
#    LG
# 0   A
# 1  A-
# 2   F
# 3   C
# 4   A
#
# ...

# %%
cols = df.columns.tolist()
cols
# Out:
# ['ID',
#  'BANCQ',
#  'BAN20',
#  'ENGCQ',
#  'ENG20',
#  'BGSCQ',
#  'BGS20',
#  'MathCQ',
#  'Math20',
#  'PhyCQ',
#  'Phy20',
#  'HMCQ',
#  'HM20',
#  'BioCQ',
#  'Bio20',
#  'ReliCQ',
#  'Reli20',
#  'CheCQ',
#  'Che20',
#  'BanTTL',
#  'BanGP',
#  'BanGL',
#  'EngTTL',
#  'EngGP',
#  'EngGL',
#  'BGSTTL',
#  'BGSGP',
#  'BGSGL',
#  'PhyTTL',
#  'PhyGP',
#  'PhyGL',
#  'HMTTL',
#  'HMGP',
#  'HMGL',
#  'BioTTL',
#  'BioGP',
#  'BioGL',
#  'ReliTTL',
#  'ReliGP',
#  'ReliGL',
#  'CheTTL',
#  'CheGP',
#  'CheGL',
#  'MathTTL',
#  'MathGP',
#  'MathGL',
#  'TTLMark',
#  'TTLGPA',
#  'GPA',
#  'LG',
#  'Position']

# %%
# Rearrange Columns 
df = df[['ID', 'BANCQ', 'BAN20','BanTTL', 'BanGP', 'BanGL',
         'ENGCQ', 'ENG20','EngTTL', 'EngGP', 'EngGL',
         'MathCQ',  'Math20','MathTTL', 'MathGP', 'MathGL',
         'BGSCQ', 'BGS20','BGSTTL',  'BGSGP', 'BGSGL',
         'ReliCQ', 'Reli20', 'ReliTTL', 'ReliGP',  'ReliGL',
         'PhyCQ', 'Phy20', 'PhyTTL', 'PhyGP', 'PhyGL',
         'CheCQ', 'Che20', 'CheTTL',  'CheGP',  'CheGL',
         'BioCQ', 'Bio20', 'BioTTL',  'BioGP', 'BioGL',
         'HMCQ', 'HM20', 'HMTTL', 'HMGP', 'HMGL',
         'TTLMark','Per', 'TTLGPA', 'GPA', 'LG', 'Position']]

# %%
df.to_csv('X_Final.csv', index = False)

# %%
pd.options.display.float_format = "{:,.0f}".format # Two precision point

# %%
df.head()
# Out:
#     ID  BANCQ  BAN20  BanTTL  BanGP BanGL  ENGCQ  ENG20  EngTTL  EngGP  ...  \
# 36  43     24     16      40      5    A+     22     19      41      5  ...
# 6    7     25     13      38      4     A     25     15      40      5  ...
# 15  17     25     15      40      5    A+     17     12      29      3  ...
# 5    6     25     16      41      5    A+     20     15      35      4  ...
# 0    1     23     16      39      4     A     20     19      39      4  ...
#
#    HM20  HMTTL  HMGP  HMGL  TTLMark Per  TTLGPA  GPA  LG  Position
# 36   19     43     5    A+      381  85      44    5   A         1
# 6    18     46     5    A+      386  86      43    5   A         2
# 15   15     43     5    A+      383  85      43    5   A         3
# 5    15     45     5    A+      382  85      43    5   A         4
# 0    15     43     5    A+      383  85      42    5   A         5
#
# [5 rows x 52 columns]

# %%
df['Per'] = df['TTLMark'] /450 * 100
df.round({'Per': 2})
# Out:
#     ID  BANCQ  BAN20  BanTTL  BanGP BanGL  ENGCQ  ENG20  EngTTL  EngGP  ...  \
# 0   43     24     16      40      5    A+     22     19      41      5  ...
# 1    7     25     13      38      4     A     25     15      40      5  ...
# 2   17     25     15      40      5    A+     17     12      29      3  ...
# 3    6     25     16      41      5    A+     20     15      35      4  ...
# 4    1     23     16      39      4     A     20     19      39      4  ...
# 5   26     20     13      33      4    A-     19     15      34      4  ...
# 6    5     24     17      41      5    A+     26     13      39      4  ...
# 7   12     25     11      36      4     A     27     14      41      5  ...
# 8   24     20     15      35      4     A     20     17      37      4  ...
# 9   14     24     14      38      4     A     18     13      31      4  ...
# 10  31     18     16      34      4    A-     15     10      25      3  ...
# ...

# %%
df.head()
# Out:
#    ID  BANCQ  BAN20  BanTTL  BanGP BanGL  ENGCQ  ENG20  EngTTL  EngGP  ...  \
# 0  43   24.0   16.0    40.0    5.0    A+   22.0   19.0    41.0    5.0  ...
# 1   7   25.0   13.0    38.0    4.0     A   25.0   15.0    40.0    5.0  ...
# 2  17   25.0   15.0    40.0    5.0    A+   17.0   12.0    29.0    3.0  ...
# 3   6   25.0   16.0    41.0    5.0    A+   20.0   15.0    35.0    4.0  ...
# 4   1   23.0   16.0    39.0    4.0     A   20.0   19.0    39.0    4.0  ...
#
#    HM20  HMTTL  HMGP  HMGL  TTLMark    Per  TTLGPA   GPA  LG  Position
# 0  19.0   43.0   5.0    A+    381.0  84.67    44.0  4.89   A         1
# 1  18.0   46.0   5.0    A+    386.0  85.78    43.0  4.78   A         2
# 2  15.0   43.0   5.0    A+    383.0  85.11    43.0  4.78   A         3
# 3  15.0   45.0   5.0    A+    382.0  84.89    43.0  4.78   A         4
# 4  15.0   43.0   5.0    A+    383.0  85.11    42.0  4.67   A         5
#
# [5 rows x 52 columns]

# %%
# Create Message
for (row, rowseries) in df.iterrows():
    #print(row)
    #print(rowseries)
    message = ''' 
                    HOLY LAND College
                    1st Term Mark Sheet-2021
                   .......................... 
    Id: {} of Clas IX        Obtain postion: {}
    {} : {}, {} : {}, {} : {}, {} : {}, {} : {}    
    {} : {}, {} : {}, {} : {}, {} : {}, {} : {}    
    {} : {}, {} : {}, {} : {}, {} : {}, {} : {}    
    {} : {}, {} : {}, {} : {}, {} : {}, {} : {}
    {} : {}, {} : {}, {} : {}, {} : {}, {} : {}    
    {} : {}, {} : {}, {} : {}, {} : {}, {} : {}  
    {} : {}, {} : {}, {} : {}, {} : {}, {} : {}    
    {} : {}, {} : {}, {} : {}, {} : {}, {} : {}
    {} : {}, {} : {}, {} : {}, {} : {}, {} : {}    
    {} : {}, {} : {}, {} : {}, {} : {}, {} : {} 
            
    '''.format(rowseries[0], rowseries[51],
               rowseries.index[1],rowseries[1],
               rowseries.index[2],rowseries[2],  
               rowseries.index[3],rowseries[3], 
               rowseries.index[4],rowseries[4], 
               rowseries.index[5],rowseries[5],
               rowseries.index[6],rowseries[6],
               rowseries.index[7],rowseries[7],  
               rowseries.index[8],rowseries[8], 
                rowseries.index[9],rowseries[9], 
               rowseries.index[10],rowseries[10],
                rowseries.index[11],rowseries[11],
               rowseries.index[12],rowseries[12],  
               rowseries.index[13],rowseries[13], 
               rowseries.index[14],rowseries[14], 
               rowseries.index[15],rowseries[15],
               rowseries.index[16],rowseries[16],
               rowseries.index[17],rowseries[17],  
               rowseries.index[18],rowseries[18], 
                rowseries.index[19],rowseries[19], 
               rowseries.index[20],rowseries[20],
                rowseries.index[21],rowseries[21],
               rowseries.index[22],rowseries[22],  
               rowseries.index[23],rowseries[23], 
               rowseries.index[24],rowseries[24], 
               rowseries.index[25],rowseries[25],
               rowseries.index[26],rowseries[26],
               rowseries.index[27],rowseries[27],  
               rowseries.index[28],rowseries[28], 
                rowseries.index[29],rowseries[29], 
               rowseries.index[30],rowseries[30],
               rowseries.index[31],rowseries[31],
               rowseries.index[32],rowseries[32],  
               rowseries.index[33],rowseries[33], 
               rowseries.index[34],rowseries[34], 
               rowseries.index[35],rowseries[35],
               rowseries.index[36],rowseries[36],
               rowseries.index[37],rowseries[37],  
               rowseries.index[38],rowseries[38], 
                rowseries.index[39],rowseries[39], 
               rowseries.index[40],rowseries[40],
                rowseries.index[41],rowseries[41],
               rowseries.index[42],rowseries[42],  
               rowseries.index[43],rowseries[43], 
               rowseries.index[44],rowseries[44], 
               rowseries.index[45],rowseries[45],
               rowseries.index[46],rowseries[46],
               rowseries.index[47],rowseries[47],  
               rowseries.index[48],rowseries[48],
               rowseries.index[49],rowseries[49], 
               rowseries.index[50],rowseries[50])
    print(message)
# Out:
#
#                     HOLY LAND College
#                     1st Term Mark Sheet-2021
#                    ..........................
#     Id: 43 of Clas IX        Obtain postion: 1
#     BANCQ : 24.0, BAN20 : 16.0, BanTTL : 40.0, BanGP : 5.0, BanGL : A+
#     ENGCQ : 22.0, ENG20 : 19.0, EngTTL : 41.0, EngGP : 5.0, EngGL : A+
#     MathCQ : 24.0, Math20 : 14.0, MathTTL : 38.0, MathGP : 4.0, MathGL : A
#     BGSCQ : 27.0, BGS20 : 17.0, BGSTTL : 44.0, BGSGP : 5.0, BGSGL : A+
#     ReliCQ : 29.0, Reli20 : 17.0, ReliTTL : 46.0, ReliGP : 5.0, ReliGL : A+
#     PhyCQ : 27.0, Phy20 : 13.0, PhyTTL : 40.0, PhyGP : 5.0, PhyGL : A+
#     CheCQ : 28.0, Che20 : 18.0, CheTTL : 46.0, CheGP : 5.0, CheGL : A+
#     BioCQ : 23.0, Bio20 : 20.0, BioTTL : 43.0, BioGP : 5.0, BioGL : A+
#     HMCQ : 24.0, HM20 : 19.0, HMTTL : 43.0, HMGP : 5.0, HMGL : A+
#     TTLMark : 381.0, Per : 84.67, TTLGPA : 44.0, GPA : 4.89, LG : A
#
#
#
#                     HOLY LAND College
# ...

# %%
# Create Message
for (row, rowseries) in df.iterrows():
    #print(row)
    #print(rowseries)
    message = ''' 
                    HOLY LAND College
                    1st Term Mark Sheet-2021
                   .......................... 
    Id: {} of Clas IX        Obtain postion: {}
    ..............................................
    Sub   CQ    |  MCQ    |  TTL    |  GP   |  LG
    ..............................................
    Ban   {}  |  {}   |  {}   |  {}  |  {}
    Eng   {}  |  {}   |  {}   |  {}  |  {}
    Math  {}  |  {}   |  {}   |  {}  |  {}
    BGS   {}  |  {}   |  {}   |  {}  |  {}
    Reli  {}  |  {}   |  {}   |  {}  |  {}
    Phy   {}  |  {}   |  {}   |  {}  |  {}
    Che   {}  |  {}   |  {}   |  {}  |  {}
    Bio   {}  |  {}   |  {}   |  {}  |  {}
    HM    {}  |  {}   |  {}   |  {}  |  {}
    {} : {}, {} : {}, {} : {}, {} : {}  
            
    '''.format(rowseries[0], rowseries[51],
              rowseries[1],
              rowseries[2],  
               rowseries[3], 
               rowseries[4], 
               rowseries[5],
               rowseries[6],
               rowseries[7],  
               rowseries[8], 
               rowseries[9], 
               rowseries[10],
               rowseries[11],
               rowseries[12],  
               rowseries[13], 
               rowseries[14], 
               rowseries[15],
               rowseries[16],
               rowseries[17],  
               rowseries[18], 
               rowseries[19], 
               rowseries[20],
               rowseries[21],
              rowseries[22],  
               rowseries[23], 
               rowseries[24], 
               rowseries[25],
               rowseries[26],
               rowseries[27],  
               rowseries[28], 
               rowseries[29], 
               rowseries[30],
               rowseries[31],
              rowseries[32],  
               rowseries[33], 
               rowseries[34], 
               rowseries[35],
               rowseries[36],
               rowseries[37],  
               rowseries[38], 
               rowseries[39], 
               rowseries[40],
               rowseries[41],
               rowseries[42],  
               rowseries[43], 
               rowseries[44], 
               rowseries[45],
               rowseries.index[46],rowseries[46],
               rowseries.index[47],rowseries[47],  
               rowseries.index[49],rowseries[49], 
               rowseries.index[50],rowseries[50])
    print(message)
# Out:
#
#                     HOLY LAND College
#                     1st Term Mark Sheet-2021
#                    ..........................
#     Id: 43 of Clas IX        Obtain postion: 1
#     ..............................................
#     Sub   CQ    |  MCQ    |  TTL    |  GP   |  LG
#     ..............................................
#     Ban   24.0  |  16.0   |  40.0   |  5.0  |  A+
#     Eng   22.0  |  19.0   |  41.0   |  5.0  |  A+
#     Math  24.0  |  14.0   |  38.0   |  4.0  |  A
#     BGS   27.0  |  17.0   |  44.0   |  5.0  |  A+
#     Reli  29.0  |  17.0   |  46.0   |  5.0  |  A+
#     Phy   27.0  |  13.0   |  40.0   |  5.0  |  A+
#     Che   28.0  |  18.0   |  46.0   |  5.0  |  A+
#     Bio   23.0  |  20.0   |  43.0   |  5.0  |  A+
#     HM    24.0  |  19.0   |  43.0   |  5.0  |  A+
#     TTLMark : 381.0, Per : 84.67, GPA : 4.89, LG : A
#
#
#
#                     HOLY LAND College
#                     1st Term Mark Sheet-2021
# ...

# %%
print('message')
# Out:
# message

# %%
from tabulate import tabulate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-5df088049afd> in <module>
# ----> 1 from tabulate import tabulate
#
# ModuleNotFoundError: No module named 'tabulate'

# %%
df['LG'] =np.where(df['GPA']>=5, 'A+', np.where(df['GPA']>=4, 'A',np.where(df['GPA']>=3.5, 'A-',np.where(df['GPA']>=3, 'B', np.where(df['GPA']>=2, 'C','F')))))

# %%
df.to_csv("IXResul.csv")

# %%
df['GPA']=if(or(df['BANGP'],df['ENGGP'],df['MathGP'],df['BGSGP'],df['ReliGP'],df['PhyGP'],df['CheGP'],df['BioGP'],df['HMGP'])==0,0,df['GPGPA']/9)
# Out:
#   File "<ipython-input-12-105b99ddf0eb>", line 1
#     df['GPA']=if(or(df['BANGP'],df['ENGGP'],df['MathGP'],df['BGSGP'],df['ReliGP'],df['PhyGP'],df['CheGP'],df['BioGP'],df['HMGP'])==0,0,df['GPGPA']/9)
#               ^
# SyntaxError: invalid syntax

# %%
df['xx']=if((df['BANGP']==0|df['ENGGP']==0|df['MathGP']==0|df['BGSGP']==0|df['ReliGP']==0|df['PhyGP']==0|df['CheGP']==0|df['BioGP']==0|df['HMGP']==0),0,df['GPGPA']/9)
# Out:
#   File "<ipython-input-14-0ba07966162b>", line 1
#     df['xx']=if((df['BANGP']==0|df['ENGGP']==0|df['MathGP']==0|df['BGSGP']==0|df['ReliGP']==0|df['PhyGP']==0|df['CheGP']==0|df['BioGP']==0|df['HMGP']==0),0,df['GPGPA']/9)
#              ^
# SyntaxError: invalid syntax

# %%
df['ICTGP'] =np.where(2*df['ICT25']>39, 5, np.where(2*df['ICT25']>34, 4,np.where(2*df['ICT25']>29, 3.5,np.where(2*df['ICT25']>24, 3, np.where(2*df['ICT25']>19, 2,0)))))
df['ICTGL'] =np.where(df['ICTGP']==5, 'A+', np.where(df['ICTGP']==4, 'A',np.where(df['ICTGP']==3.5, 'A-',np.where(df['ICTGP']==3, 'B', np.where(df['ICTGP']==2, 'C','F')))))
