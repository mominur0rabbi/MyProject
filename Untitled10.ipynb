# %%
import pandas as pd

# %%
df = pd.read_csv('comment_xi.csv')

# %%
df.head()
# Out:
#         Id group  sex                   c1   c2                   c3   c4  \
# 0  3200001   Com    G  26/08/2020\n9,000/-  NaN  26/08/2020\n9,000/-  NaN
# 1  3200002   Com  boy  26/08/2020\n9,000/-  NaN  26/08/2020\n9,000/-  NaN
# 2  3200003   Com    G  26/08/2020\n9,000/-  NaN  26/08/2020\n9,000/-  NaN
# 3  3200004   Com    G  27/08/2020\n9,000/-  NaN  27/08/2020\n9,000/-  NaN
# 4  3200005   Com  boy  27/08/2020\n9,000/-  NaN  27/08/2020\n9,000/-  NaN
#
#                     c5   c6  \
# 0  26/08/2020\n9,000/-  NaN
# 1  26/08/2020\n9,000/-  NaN
# 2  26/08/2020\n9,000/-  NaN
# 3  27/08/2020\n9,000/-  NaN
# 4  27/08/2020\n9,000/-  NaN
#
#                                                   c7  ...  \
# 0  26/08/2020\n9,000/-\n\n28/01/21\n1682\nO/fee=6...  ...
# 1                                26/08/2020\n9,000/-  ...
# 2                                26/08/2020\n9,000/-  ...
# 3                                27/08/2020\n9,000/-  ...
# ...

# %%
df1 = pd.DataFrame(data=df)

# %%
df1_transposed = df1.T

# %%
df1_trnsposed.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-86a0d69429c6> in <module>
# ----> 1 df1_trnsposed.head()
#
# NameError: name 'df1_trnsposed' is not defined

# %%
df1_transposed.to_csv('N_comment.csv', index = False)

# %%
df = pd.read_csv('N_comment.csv')

# %%
print(df.duplicated(subset=['com1']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-f5193a43a1a2> in <module>
# ----> 1 print(df.duplicated(subset=['com1']))
#
# ~\anaconda33\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    5403         diff = Index(subset).difference(self.columns)
#    5404         if not diff.empty:
# -> 5405             raise KeyError(diff)
#    5406
#    5407         vals = (col.values for name, col in self.items() if name in subset)
#
# KeyError: Index(['com1'], dtype='object')

# %%
df = pd.read_csv('N_comment.csv')

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 500)

# %%
print(df[df.duplicated(subset=['AB'])])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-1a192967a399> in <module>
# ----> 1 print(df[df.duplicated(subset=['AB'])])
#
# ~\anaconda33\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    5403         diff = Index(subset).difference(self.columns)
#    5404         if not diff.empty:
# -> 5405             raise KeyError(diff)
#    5406
#    5407         vals = (col.values for name, col in self.items() if name in subset)
#
# KeyError: Index(['AB'], dtype='object')

# %%
df = df.astype(str)

# %%
df = pd.read_csv('New_comment.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-f771df57e616> in <module>
# ----> 1 df = pd.read_csv('New_comment.csv')
#
# ~\anaconda33\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# ...

# %%
df.to_csv('New_comment.csv', index = False)

# %%
print(df[df.duplicated(subset=['AB'])])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-1a192967a399> in <module>
# ----> 1 print(df[df.duplicated(subset=['AB'])])
#
# ~\anaconda33\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    5403         diff = Index(subset).difference(self.columns)
#    5404         if not diff.empty:
# -> 5405             raise KeyError(diff)
#    5406
#    5407         vals = (col.values for name, col in self.items() if name in subset)
#
# KeyError: Index(['AB'], dtype='object')

# %%
df = pd.read_csv('New_comment.csv')

# %%
print(df[df.duplicated(subset=['AB'])])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-1a192967a399> in <module>
# ----> 1 print(df[df.duplicated(subset=['AB'])])
#
# ~\anaconda33\lib\site-packages\pandas\core\frame.py in duplicated(self, subset, keep)
#    5403         diff = Index(subset).difference(self.columns)
#    5404         if not diff.empty:
# -> 5405             raise KeyError(diff)
#    5406
#    5407         vals = (col.values for name, col in self.items() if name in subset)
#
# KeyError: Index(['AB'], dtype='object')

# %%
df = pd.read_csv('N_com.csv')

# %%
df
# Out:
#                                                    AB  \
# 0                                             3200001
# 1                                                 Com
# 2                                                   G
# 3                                 26/08/2020\n9,000/-
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   26/08/2020\n9,000/-\n\n28/01/21\n1682\nO/fee=6...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  28/01/21\n1682\nO/fee=6500\nOct to Janu/21\nPa...
# 14                                                NaN
# 15                                                NaN
# ...

# %%
print(df[~df.duplicated(subset=['AB'])])
# Out:
#                                                    AB                   AC  \
# 0                                             3200001              3200002
# 1                                                 Com                  Com
# 2                                                   G                  boy
# 3                                 26/08/2020\n9,000/-  26/08/2020\n9,000/-
# 4                                                 NaN                  NaN
# 9   26/08/2020\n9,000/-\n\n28/01/21\n1682\nO/fee=6...                  NaN
# 13  28/01/21\n1682\nO/fee=6500\nOct to Janu/21\nPa...                  NaN
#
#                                             Com3                 Com4  \
# 0                                        3200003              3200004
# 1                                            Com                  Com
# 2                                              G                    G
# 3                            26/08/2020\n9,000/-  27/08/2020\n9,000/-
# ...

# %%
df.to_csv('New_comment.csv', index = False)

# %%
df = pd.read_csv('New_comment.csv')

# %%
df_transposed = df.T

# %%
df_transposed.to_csv('F_comment.csv', index = False)
