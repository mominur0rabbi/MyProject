# %%
import pandas as pd

# %%
df =pd.read_csv('HSC_Ban_01S.csv', usecols=['Name', 'Points Earned'])
print(df)
# Out:
#              Name  Points Earned
# 0    01190002SASA           23.0
# 1    01190003EXAM           25.0
# 2    01190004HLCR           20.0
# 3    01190008MIRA           19.0
# 4    01190010HLCN           15.0
# ..            ...            ...
# 151  02190021Exam           19.0
# 152  02190022HLCT           15.0
# 153  02190025anna           14.0
# 154  02190026Babu           19.0
# 155  02190033J@nu           19.0
#
# [156 rows x 2 columns]

# %%
df = pd.read_csv('file.csv', usecols=['column_name'])

# %%
df=df.rename(columns={'Points Earned': 'Ban1st'})
df.head()
# Out:
#            Name  Ban1st
# 0  01190002SASA    23.0
# 1  01190003EXAM    25.0
# 2  01190004HLCR    20.0
# 3  01190008MIRA    19.0
# 4  01190010HLCN    15.0

# %%
df.to_csv('Ban1stSc.csv', index=False)

# %%
df = df.set_axis(['Name', 'X', 'Y', 'Z', 'P', 'Ban1st'], axis=1, inplace=False)
# Out:
#              Name  Points Earned
# 0    01190002SASA           23.0
# 1    01190003EXAM           25.0
# 2    01190004HLCR           20.0
# 3    01190008MIRA           19.0
# 4    01190010HLCN           15.0
# ..            ...            ...
# 151  02190021Exam           19.0
# 152  02190022HLCT           15.0
# 153  02190025anna           14.0
# 154  02190026Babu           19.0
# 155  02190033J@nu           19.0
#
# [156 rows x 2 columns]

# %%
df = df.set_axis(['Name', 'X', 'Y', 'Z', 'P', 'Ban1st'], axis=1, inplace=False)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-6d1ea8f92668> in <module>
# ----> 1 df = df.set_axis(['Name', 'X', 'Y', 'Z', 'P', 'Ban1st'], axis=1, inplace=False)
#       2 df
#
# ~\anaconda33\lib\site-packages\pandas\core\frame.py in set_axis(self, labels, axis, inplace)
#    4153     @Appender(NDFrame.set_axis.__doc__)
#    4154     def set_axis(self, labels, axis: Axis = 0, inplace: bool = False):
# -> 4155         return super().set_axis(labels, axis=axis, inplace=inplace)
#    4156
#    4157     @Substitution(**_shared_doc_kwargs)
#
# ~\anaconda33\lib\site-packages\pandas\core\generic.py in set_axis(self, labels, axis, inplace)
#     654         """
#     655         self._check_inplace_and_allows_duplicate_labels(inplace)
# --> 656         return self._set_axis_nocheck(labels, axis, inplace)
#     657
#     658     @final
#
# ...

# %%
df_copy = df.copy()
df_copy.rename(columns={'Points Earned': 'Ban1st'})
df_copy.head()
# Out:
#            Name             Start Datetime               End Datetime  \
# 0  01190002SASA  2021-06-15 17:31:09+06:00  2021-06-15 17:52:49+06:00
# 1  01190003EXAM  2021-06-15 17:30:21+06:00  2021-06-15 17:57:01+06:00
# 2  01190004HLCR  2021-06-15 17:30:48+06:00  2021-06-15 17:56:44+06:00
# 3  01190008MIRA  2021-06-15 17:30:26+06:00  2021-06-15 17:45:05+06:00
# 4  01190010HLCN  2021-06-15 17:57:36+06:00  2021-06-15 18:06:35+06:00
#
#       Time  Percent  Points Earned  Points Possible  \
# 0  0:21:00       77           23.0             30.0
# 1  0:25:40       83           25.0             30.0
# 2  0:24:20       67           20.0             30.0
# 3  0:13:57       63           19.0             30.0
# 4  0:07:51       50           15.0             30.0
#
#    ‘লালসালু’ কী ধরণের উপন্যাস?  কোন ঘটনায় অনুপমের মন পুলকের আবেশে ভরে যায়?  \
# 0                          0.0                                          0.0
# ...
