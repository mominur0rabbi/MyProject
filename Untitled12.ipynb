# %%
# importing pandas package
import pandas as pd

# %%
# making data frame from csv file
data = pd.read_csv("comment.csv")

# %%
# sorting by first name
data.sort_values("com101", inplace = True)

# %%
# dropping ALL duplicte values
data.drop_duplicates(subset ="AB",
                     keep = False, inplace = True)

# %%
# displaying data
data
# Out:
#                                                   AB                 Com2  \
# 0                                26/08/2020\n9,000/-       06/06/21\n1707
# 1  26/08/2020\n9,000/-\n\n28/01/21\n1682\nO/fee=6...       25/01/21\n1706
# 2  28/01/21\n1682\nO/fee=6500\nOct to Janu/21\nPa...  26/08/2020\n9,000/-
#
#                                                 Com3  \
# 0  05/12/2020\n1731\nNov/20\n10/01/2021\nBy bkash...
# 1       06/04/2021\nBy bkash\nC=2870\nH=1950\nT=4820
# 2  07/11/2020\n1730\nOct/2020\n05/12/2020\n1731\n...
#
#                                                 Com4  \
# 0                                27/08/2020\n9,000/-
# 1      28/01/21\n1754\nOct + Nov/20\nPaid in janu/21
# 2  29/04/2021\n1756\nDec/20 to April/21\nO/fee=65...
#
#                                                 Com5  \
# 0       09/11/2020\nBy bkash\nC=2170\nH=2160\nT=4330
# 1  11.10.2020\nBkash=10,830/-\nCollege=8,670/-\nH...
# 2  13/12/2020\nBy bkash\nC=2170\nH=2160\nT=4330\n...
#
# ...

# %%
data.sort_values("Com101", inplace = True)

# %%
data.drop_duplicates(subset ="Com101",
                     keep = False, inplace = True)

# %%
data.sort_values("Com103", inplace = True)
data.drop_duplicates(subset ="Com103",
                     keep = False, inplace = True)

# %%
data.sort_values("Com103", inplace = True)

# %%
data.sort_values("Com105", inplace = True)
data.drop_duplicates(subset ="Com105",
                     keep = False, inplace = True)
data.sort_values("Com105", inplace = True)

# %%
data
# Out:
#                     AB            Com2  \
# 0  26/08/2020\n9,000/-  06/06/21\n1707
#
#                                                 Com3                 Com4  \
# 0  05/12/2020\n1731\nNov/20\n10/01/2021\nBy bkash...  27/08/2020\n9,000/-
#
#                                            Com5  \
# 0  09/11/2020\nBy bkash\nC=2170\nH=2160\nT=4330
#
#                             Com6                Com7  \
# 0  05/06/21\n1928\nUp to June/21  07/11/2020\n1951\n
#
#                                            Com8  \
# 0  03/05/21\nBy bkash\nC=14280\nH=2910\nT=17190
#
#                                                 Com9  \
# 0  07/01/2021\n2048\n27/01/2021\n2049\nDec/20\nPa...
#
#                                                Com10  ...  \
# 0  28/01/21\n2070\nOct to Janu/21\nO/fee=6500\nPa...  ...
#
#                 Com447               Com448                     Com449  \
# 0  19/09/2020\n7,500/-  19/09/2020\n7,500/-  20/09/2020\n3481\n7,500/-
#
# ...

# %%
data.head()
# Out:
#                     AB            Com2  \
# 0  26/08/2020\n9,000/-  06/06/21\n1707
#
#                                                 Com3                 Com4  \
# 0  05/12/2020\n1731\nNov/20\n10/01/2021\nBy bkash...  27/08/2020\n9,000/-
#
#                                            Com5  \
# 0  09/11/2020\nBy bkash\nC=2170\nH=2160\nT=4330
#
#                             Com6                Com7  \
# 0  05/06/21\n1928\nUp to June/21  07/11/2020\n1951\n
#
#                                            Com8  \
# 0  03/05/21\nBy bkash\nC=14280\nH=2910\nT=17190
#
#                                                 Com9  \
# 0  07/01/2021\n2048\n27/01/2021\n2049\nDec/20\nPa...
#
#                                                Com10  ...  \
# 0  28/01/21\n2070\nOct to Janu/21\nO/fee=6500\nPa...  ...
#
#                 Com447               Com448                     Com449  \
# 0  19/09/2020\n7,500/-  19/09/2020\n7,500/-  20/09/2020\n3481\n7,500/-
#
# ...

# %%
data.to_csv('test.csv', index =False)

# %%
data.sort_values("Com101", inplace = True)

# %%
data
# Out:
#                                                   AB  \
# 0                                26/08/2020\n9,000/-
# 1  26/08/2020\n9,000/-\n\n28/01/21\n1682\nO/fee=6...
# 2  28/01/21\n1682\nO/fee=6500\nOct to Janu/21\nPa...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#                                   Com2  \
# 0                       06/06/21\n1707
# 1                       25/01/21\n1706
# 2                  26/08/2020\n9,000/-
# 3  Less 30% in Tuition fee for Oct/20.
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
#
#                                                 Com3  \
# 0  05/12/2020\n1731\nNov/20\n10/01/2021\nBy bkash...
# ...

# %%
data.sort_values("Com101", inplace = True)

# %%
data
# Out:
#                                                   AB  \
# 0                                26/08/2020\n9,000/-
# 1  26/08/2020\n9,000/-\n\n28/01/21\n1682\nO/fee=6...
# 2  28/01/21\n1682\nO/fee=6500\nOct to Janu/21\nPa...
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
#
#                                   Com2  \
# 0                       06/06/21\n1707
# 1                       25/01/21\n1706
# 2                  26/08/2020\n9,000/-
# 3  Less 30% in Tuition fee for Oct/20.
# 4                                  NaN
# 5                                  NaN
# 6                                  NaN
# 7                                  NaN
#
#                                                 Com3  \
# 0  05/12/2020\n1731\nNov/20\n10/01/2021\nBy bkash...
# ...

# %%
data.drop_duplicates(subset ="Com101",
                     keep = False, inplace = True)

# %%
data
# Out:
#                                                   AB            Com2  \
# 0                                26/08/2020\n9,000/-  06/06/21\n1707
# 1  26/08/2020\n9,000/-\n\n28/01/21\n1682\nO/fee=6...  25/01/21\n1706
#
#                                                 Com3  \
# 0  05/12/2020\n1731\nNov/20\n10/01/2021\nBy bkash...
# 1       06/04/2021\nBy bkash\nC=2870\nH=1950\nT=4820
#
#                                             Com4  \
# 0                            27/08/2020\n9,000/-
# 1  28/01/21\n1754\nOct + Nov/20\nPaid in janu/21
#
#                                                 Com5  \
# 0       09/11/2020\nBy bkash\nC=2170\nH=2160\nT=4330
# 1  11.10.2020\nBkash=10,830/-\nCollege=8,670/-\nH...
#
#                             Com6                            Com7  \
# 0  05/06/21\n1928\nUp to June/21              07/11/2020\n1951\n
# 1                 25/01/21\n1927  10/10/20\n1950\npaid to Oct/20
#
#                                            Com8  \
# ...
