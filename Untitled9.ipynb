# %%
import pandas as pd

# %%
col = pd.read_csv('college.csv')

# %%
hos = pd.read_csv('Hostel.csv')
hos.head()
# Out:
#         Id                       Name Group          Gmob H_Name   H_Rent  \
# 0  2200004               �mq`  �nv�mb   Sci  1.738174e+09   we-2   6,800
# 1  2200007            AvivdvZ  �nv�mb   Sci  1.746447e+09   we-1   7,200
# 2  2200008          AvwZK  iv�k` Luvb   Sci  1.712702e+09   we-1   6,800
# 3  2200009   �gvt nvexe kvnvixqvi �`q   Sci  1.722939e+09   we-1   7,200
# 4  2200015  �gvt dvwng kvnvixi �mvnvb   Sci  1.740845e+09   we-2   7,200
#
#   Adm_Dt Lea_dt    H_Dues  H_Afees  ... Unnamed: 63 Unnamed: 64 Unnamed: 65  \
# 0    NaN    NaN   16,320    4,000   ...         NaN         NaN         NaN
# 1    NaN    NaN   10,800    4,000   ...         NaN         NaN         NaN
# 2    NaN    NaN        -    4,000   ...         NaN         NaN         NaN
# 3    NaN    NaN        -    4,000   ...         NaN         NaN         NaN
# 4    NaN    NaN   17,280    4,000   ...         NaN         NaN         NaN
#
# ...

# %%
comb = pd.merge(col, hos, how = 'outer')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-7-9e0582c038ef> in <module>
# ----> 1 comb = pd.merge(col, hos, how = 'outer')
#
# ~\anaconda33\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda33\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     648             warnings.warn(msg, UserWarning)
#     649
# --> 650         self._validate_specification()
#     651
#     652         cross_col = None
#
# ...

# %%
comb = pd.merge(col, hos, how = 'outer')
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-8-9e0582c038ef> in <module>
# ----> 1 comb = pd.merge(col, hos, how = 'outer')
#
# ~\anaconda33\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~\anaconda33\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     648             warnings.warn(msg, UserWarning)
#     649
# --> 650         self._validate_specification()
#     651
#     652         cross_col = None
#
# ...
